# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/2024/11/13/llm-engineering-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/12/21/llm-resources-superdatascience/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/nvidia/parakeet-tdt-0.6b-v2',
#  '/nari-labs/Dia-1.6B',
#  '/lodestones/Chroma',
#  '/PrimeIntellect/INTELLECT-2',
#  '/Wan-AI/Wan2.1-VACE-14B',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/smolagents/computer-agent',
#  '/spaces/ByteDance/DreamO',
#  '/spaces/Heartsync/NSFW-Uncensored-video',
#  '/spaces/NihalGazi/FLUX-Pro-Unlimited',
#  '/spaces',
#  '/datasets/openbmb/Ultra-FineWeb',
#  '/datasets/PrimeIntellect/INTELLECT-2-RL-Dataset',
#  '/datasets/nvidia/OpenCodeReasoning',
#  '/datasets/nvidia/OpenMathReasoning',
#  '/datasets/DMindAI/DMind_Benchmark',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community discussion page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# nvidia/parakeet-tdt-0.6b-v2
# Updated
# 3 days ago
# •
# 243k
# •
# 933
# nari-labs/Dia-1.6B
# Updated
# 5 days ago
# •
# 181k
# •
# 2.22k
# lodestones/Chroma
# Updated
# about 8 hours ago
# •
# 576
# PrimeIntellect/INTELLECT-2
# Updated
# 6 days ago
# •
# 632
# •
# 162
# Wan-AI/Wan2.1-VACE-14B
# Updated
# 4 days ago
# •
# 8.8k
# •
# 154
# Browse 1M+ models
# Spaces
# Running
# 6.7k
# 6.7k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# CPU Upgrade
# 673
# 673
# Computer Agent
# 🖥
# Interact with an AI agent to perform web tasks
# Running
# on
# Zero
# 392
# 392
# DreamO
# 🐨
# A Unified Framework for Image Customization
# Running
# on
# Zero
# 219
# 219
# NSFW Uncensored image to video
# 🎬
# MAX ~60sec Video - AI Limits
# Running
# 426
# 426
# FLUX Pro Unlimited
# 🔥
# Use the FLUX-Pro model as much as you want.
# Browse 400k+ applications
# Datasets
# openbmb/Ultra-FineWeb
# Updated
# 10 days ago
# •
# 6.63k
# •
# 67
# PrimeIntellect/INTELLECT-2-RL-Dataset
# Updated
# 6 days ago
# •
# 517
# •
# 44
# nvidia/OpenCodeReasoning
# Updated
# 14 days ago
# •
# 12.7k
# •
# 415
# nvidia/OpenMathReasoning
# Updated
# 9 days ago
# •
# 38.4k
# •
# 236
# DMindAI/DMind_Benchmark
# Updated
# 1 day ago
# •
# 2.27k
# •
# 75
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 757 models
# •
# 3.28k followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.99k followers
# Amazon
# company
# •
# 20 models
# •
# 3.17k followers
# Google
# company
# •
# 991 models
# •
# 13.3k followers
# Intel
# company
# •
# 221 models
# •
# 2.54k followers
# Microsoft
# company
# •
# 374 models
# •
# 12.4k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 160 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 267 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 144,477
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 29,022
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,269
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,601
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,685
# Fast tokenizers optimized for research & production
# TRL
# 13,792
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,610
# State-of-the-art ML running directly in your browser
# smolagents
# 18,787
# Smol library to build great agents in Python
# PEFT
# 18,437
# Parameter-efficient finetuning for large language models
# Datasets
# 20,128
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,128
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,725
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 38,253
# AI & ML interests
# The AI community building the future.
# Recent Activity
# ngxson
# new
# activity
# about 5 hours ago
# huggingface/inference-playground:
# [FEEDBACK] Inference Playground
# thomasglopes
# new
# activity
# 2 days ago
# huggingface/inference-playground:
# [FEEDBACK] Inference Playground
# sayakpaul
# authored
# a paper
# 2 days ago
# Exploring the Deep Fusion of Large Language Models and Diffusion
#   Transformers for Text-to-Image Synthesis
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 43
# Team members
# 216
# +182
# +169
# +148
# +138
# +118
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 232k
# •
# •
# 46
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 13M
# •
# •
# 686
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 9.96M
# •
# 189
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 4.19M
# •
# •
# 760
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 87
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 167
# Inference Playground
# 🔋
# Set webpage theme based on user preference or system settings
# huggingface
# 2 days ago
# Running
# 7
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 3 days ago
# Running
# 402
# AI Deadlines
# ⚡
# Generate project deadlines
# huggingface
# 19 days ago
# Running
# 97
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# Apr 16
# Running
# 539
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand
# 							26
# 								spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# Mar 31
# •
# 244
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 816
# •
# •
# 62
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 26
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 14.4k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 336
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 14.7k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 4.8k
# •
# 21
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 18
# •
# 5
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 135k
# •
# •
# 81
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand
# 							16
# 								models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# 2 days ago
# •
# 52
# •
# 2.63M
# •
# 63
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 11 days ago
# •
# 1.67k
# •
# 1.01k
# •
# 23
# huggingface/badges
# Viewer
# •
# Updated
# Apr 8
# •
# 1
# •
# 1.58M
# •
# 43
# huggingface/policy-docs
# Updated
# Mar 20
# •
# 1.28k
# •
# 10
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# Mar 15
# •
# 69
# •
# 759
# •
# 7
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# Mar 4
# •
# 17
# •
# 29
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# Mar 1
# •
# 21
# •
# 32
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# Feb 28
# •
# 24
# •
# 30
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# Feb 26
# •
# 32
# •
# 77
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# Feb 25
# •
# 32
# •
# 36
# Expand
# 							42
# 								datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 363 models
# •
# 26k followers
# Shopify
# Enterprise
# company
# •
# 454 followers
# AMD
# Enterprise
# company
# •
# 141 models
# •
# 1.54k followers
# Together
# Enterprise
# company
# •
# 29 models
# •
# 595 followers
# Qwen
# Enterprise
# company
# •
# 280 models
# •
# 31.2k followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 267 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 145 followers
# Nutanix
# Enterprise
# company
# •
# 261 models
# •
# 98 followers
# creditkarma
# Enterprise
# company
# •
# 66 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 71 models
# •
# 1.35k followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 72 followers
# Skywork
# Enterprise
# company
# •
# 40 models
# •
# 686 followers
# Liquid AI
# Enterprise
# company
# •
# 192 followers
# Stability AI
# Enterprise
# company
# •
# 106 models
# •
# 23.3k followers
# Infosys Limited
# Enterprise
# company
# •
# 2 models
# •
# 828 followers
# AI at Meta
# Enterprise
# company
# •
# 2.12k models
# •
# 5.99k followers
# Snowflake
# Enterprise
# company
# •
# 21 models
# •
# 514 followers
# Arm
# Enterprise
# company
# •
# 197 followers
# LiveRAG by AIIR
# Enterprise
# company
# •
# 130 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 3 models
# •
# 276 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 165 followers
# Jusbrasil
# Enterprise
# company
# •
# 98 followers
# H2O.ai
# Enterprise
# company
# •
# 71 models
# •
# 426 followers
# Chegg Inc
# Enterprise
# company
# •
# 86 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 61 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 675 followers
# BCG X
# Enterprise
# company
# •
# 40 followers
# Twelve Labs
# Enterprise
# company
# •
# 44 followers
# Meta Llama
# Enterprise
# company
# •
# 70 models
# •
# 43.7k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 300 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 223 followers
# ServiceNow
# Enterprise
# company
# •
# 505 followers
# Xsolla
# Enterprise
# company
# •
# 137 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 115 followers
# Fidelity Investments
# Enterprise
# company
# •
# 142 followers
# IBM Granite
# Enterprise
# company
# •
# 117 models
# •
# 1.73k followers
# Aledade Inc
# Enterprise
# company
# •
# 71 followers
# HyperCLOVA X
# Enterprise
# company
# •
# 3 models
# •
# 297 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 160 followers
# Widn AI
# Enterprise
# company
# •
# 48 followers
# Lightricks
# Enterprise
# company
# •
# 13 models
# •
# 909 followers
# Adyen
# Enterprise
# company
# •
# 65 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# aws
# NVIDIA H200
# 1
# 141GB
# $5.00
# 2
# 282GB
# $10.00
# 4
# 564GB
# $20.00
# 8
# 1128GB
# $40.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with H200 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog page
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# The Transformers Library: standardizing model definitions
# By
# lysandre
# May 15, 2025
# •
# 82
# Community Articles
# view all
# Falcon-Edge: A series of powerful, universal, fine-tunable 1.58bit language models.
# By
# tiiuae
# and 9 others
# •
# 3 days ago
# •
# 31
# TinyAgents: A Minimal Experiment with Code Agents and MCP Tools
# By
# albertvillanova
# •
# 2 days ago
# •
# 22
# CycleNavigator: Visualizing Economic and Political Cycles Through AI
# By
# openfree
# •
# 5 days ago
# •
# 18
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 253
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 19 days ago
# •
# 71
# Highlights from the First ICLR 2025 Watermarking Workshop
# By
# hadyelsahar
# and 4 others
# •
# 4 days ago
# •
# 9
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 11 days ago
# •
# 25
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 75
# All LLMs Will Be Sparse BitNet Hybrids
# By
# codys12
# •
# 5 days ago
# •
# 7
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 251
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 177
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 136
# Page-to-Video: Generate videos from webpages 🪄🎬
# By
# burtenshaw
# •
# 12 days ago
# •
# 25
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 134
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 556
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 34
# A Deep Dive into Alibaba’s ZeroSearch: Why It Changes LLM-Centric Search Workflows
# By
# lynn-mikami
# •
# 6 days ago
# •
# 4
# Merge Large Language Models with mergekit
# By
# mlabonne
# •
# Jan 9, 2024
# •
# 118
# How I train a LoRA: m3lt style training overview
# By
# alvdansen
# •
# Jul 1, 2024
# •
# 52
# Introducing Pivotal Token Search (PTS): Targeting Critical Decision Points in LLM Training
# By
# codelion
# •
# 1 day ago
# •
# 3
# Improving Hugging Face Model Access for Kaggle Users
# By
# roseberryv
# May 14, 2025
# •
# 20
# Blazingly fast whisper transcriptions with Inference Endpoints
# By
# mfuntowicz
# May 13, 2025
# •
# 58
# Vision Language Models (Better, Faster, Stronger)
# By
# merve
# May 12, 2025
# •
# 317
# LeRobot Community Datasets: The “ImageNet” of Robotics — When and How?
# By
# danaaubakirova
# May 11, 2025
# •
# 45
# How to Build an MCP Server with Gradio
# By
# abidlabs
# April 30, 2025
# •
# 104
# Welcoming Llama Guard 4 on Hugging Face Hub
# By
# merve
# April 29, 2025
# •
# 36
# The 4 Things Qwen-3's Chat Template Teaches Us
# By
# cfahlgren1
# April 30, 2025
# •
# 38
# Tiny Agents: a MCP-powered agent in 50 lines of code
# By
# julien-c
# April 25, 2025
# •
# 242
# Introducing AutoRound: Intel’s Advanced Quantization for LLMs and VLMs
# By
# wenhuach
# April 29, 2025
# •
# 26
# 17 Reasons Why Gradio Isn't Just Another UI Library
# By
# ysharma
# April 16, 2025
# •
# 32
# Cohere on Hugging Face Inference Providers 🔥
# By
# burtenshaw
# April 16, 2025
# •
# 125
# Introducing HELMET
# By
# hyen
# April 16, 2025
# •
# 27
# Hugging Face to sell open-source robots thanks to Pollen Robotics acquisition 🤖
# By
# thomwolf
# April 14, 2025
# •
# 46
# 4M Models Scanned: Protect AI + Hugging Face 6 Months In
# By
# sean-pai
# April 14, 2025
# •
# 29
# Previous
# 1
# 2
# 3
# ...
# 41
# Next
# Community Articles
# Sort:
# 		Trending
# Falcon-Edge: A series of powerful, universal, fine-tunable 1.58bit language models.
# By
# tiiuae
# and 9 others
# •
# 3 days ago
# •
# 31
# TinyAgents: A Minimal Experiment with Code Agents and MCP Tools
# By
# albertvillanova
# •
# 2 days ago
# •
# 22
# CycleNavigator: Visualizing Economic and Political Cycles Through AI
# By
# openfree
# •
# 5 days ago
# •
# 18
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# Mar 17
# •
# 253
# I trained a Language Model to schedule events with GRPO!
# By
# anakin87
# •
# 19 days ago
# •
# 71
# Highlights from the First ICLR 2025 Watermarking Workshop
# By
# hadyelsahar
# and 4 others
# •
# 4 days ago
# •
# 9
# Good answers are not necessarily factual answers: an analysis of hallucination in leading LLMs
# By
# davidberenstein1957
# and 1 other
# •
# 11 days ago
# •
# 25
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 75
# All LLMs Will Be Sparse BitNet Hybrids
# By
# codys12
# •
# 5 days ago
# •
# 7
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 251
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 177
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 136
# Page-to-Video: Generate videos from webpages 🪄🎬
# By
# burtenshaw
# •
# 12 days ago
# •
# 25
# Introduction to State Space Models (SSM)
# By
# lbourdois
# •
# Jul 19, 2024
# •
# 134
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 556
# Navigating the RLHF Landscape: From Policy Gradients to PPO, GAE, and DPO for LLM Alignment
# By
# NormalUhr
# •
# Feb 11
# •
# 34
# A Deep Dive into Alibaba’s ZeroSearch: Why It Changes LLM-Centric Search Workflows
# By
# lynn-mikami
# •
# 6 days ago
# •
# 4
# Merge Large Language Models with mergekit
# By
# mlabonne
# •
# Jan 9, 2024
# •
# 118
# How I train a LoRA: m3lt style training overview
# By
# alvdansen
# •
# Jul 1, 2024
# •
# 52
# Introducing Pivotal Token Search (PTS): Targeting Critical Decision Points in LLM Training
# By
# codelion
# •
# 1 day ago
# •
# 3
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community discussion page
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Which model select?
# Beginners
# 1
# 12
# May 18, 2025
# Reproduce SFTTrainer with Accelerate and Pytorch
# 🤗Accelerate
# 0
# 6
# May 18, 2025
# Just joined Hugging Face and feeling a bit lost 😅 — how do you stay motivated when everything feels so new? Any tips for someone just starting out?
# Beginners
# 0
# 14
# May 18, 2025
# Best model to extract text from old Church records written in cursive?
# Models
# 2
# 13
# May 18, 2025
# Dedicated endpoint getting 429 errors
# Intermediate
# 2
# 17
# May 18, 2025
# PPO Training does not improve SFT model outputs (Metrics identical before and after PPO)
# 🤗Transformers
# 0
# 9
# May 18, 2025
# Wav2Vec2 WER remains 1.00 and return blank transcriptions
# Models
# 13
# 2823
# May 18, 2025
# NotImplementedError when loading dataset with Streamlit
# 🤗Datasets
# 6
# 9127
# May 17, 2025
# Huggingface trl GRPO loss is always zero
# Beginners
# 5
# 21
# May 18, 2025
# 🚩 Report: Niansuh banned
# Beginners
# 2
# 25
# May 18, 2025
# Help this newbie
# Beginners
# 6
# 77
# May 15, 2025
# RoFormer (Eng language)
# Models
# 4
# 22
# May 17, 2025
# Request for Dofollow Links on Published Blog Post (Pro User)
# Beginners
# 1
# 7
# May 17, 2025
# AI Memory : The Simplest System That Beats Every Complex Solution
# Research
# 5
# 47
# May 18, 2025
# Cant get into the AI Agents course discord
# Course
# 3
# 64
# May 18, 2025
# Has inference API stopped returning text embeddings?
# Inference Endpoints on the Hub
# 1
# 24
# May 17, 2025
# “Use this model”->Ollama: can't pull model with Q4
# 🤗Hub
# 4
# 45
# May 15, 2025
# Higher importance to new tokens
# Beginners
# 1
# 17
# May 16, 2025
# Code execution failed at line -- CodeAgents
# Beginners
# 3
# 25
# May 16, 2025
# Persistent 404 Not Found Errors with Public Inference API
# Inference Endpoints on the Hub
# 8
# 231
# May 15, 2025
# Question about llama fine tuning dataset token string
# Beginners
# 1
# 8
# May 17, 2025
# Did something change recently regarding caching / ETags?
# 🤗Hub
# 1
# 9
# May 17, 2025
# Vertex AI - The token is not valid or not have permission
# Beginners
# 17
# 1828
# May 17, 2025
# ZeroGPU space : No CUDA GPUs are available
# Spaces
# 3
# 76
# May 14, 2025
# Persistent DNS Resolution Errors
# Spaces
# 19
# 363
# May 10, 2025
# PRO subscription
# Beginners
# 1
# 31
# May 16, 2025
# Cannot verify in Discord
# Beginners
# 1
# 12
# May 16, 2025
# Getting Not Found for model google/flan-t5-small (and others)
# Beginners
# 8
# 92
# May 16, 2025
# Pre training  on a corpus of raw human thoughts : feasability and risks
# Research
# 4
# 21
# May 16, 2025
# GradioUI + Smolagents + MCP "Event loop is closed"
# Intermediate
# 1
# 12
# May 16, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# Why GitHub
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Appearance settings
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 49k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 144k
# 29k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 29k
# 6k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 20.1k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18.4k
# 1.9k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.7k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.9k
# 536
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# Handlebars
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Svelte
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 316 repositories
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 144,477
# Apache-2.0
# 28,982
# 1,048
# (2 issues need help)
# 745
# Updated
# May 18, 2025
# gym-hil
# Public
# Human in the loop Reinforcement Learning suite
# huggingface/gym-hil’s past year of commit activity
# Python
# 26
# Apache-2.0
# 1
# 1
# 2
# Updated
# May 18, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 29,022
# Apache-2.0
# 5,965
# 494
# (11 issues need help)
# 192
# Updated
# May 18, 2025
# gym-genesis
# Public
# A gym environment for GENESIS
# huggingface/gym-genesis’s past year of commit activity
# Python
# 13
# Apache-2.0
# 2
# 2
# 3
# Updated
# May 18, 2025
# open-r1
# Public
# Fully open reproduction of DeepSeek-R1
# huggingface/open-r1’s past year of commit activity
# Python
# 24,450
# Apache-2.0
# 2,250
# 260
# 36
# Updated
# May 18, 2025
# smolagents
# Public
# 🤗 smolagents: a barebones library for agents that think in python code.
# huggingface/smolagents’s past year of commit activity
# Python
# 18,788
# Apache-2.0
# 1,629
# 131
# (1 issue needs help)
# 101
# Updated
# May 18, 2025
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# huggingface/optimum’s past year of commit activity
# Python
# 2,901
# Apache-2.0
# 536
# 293
# (2 issues need help)
# 59
# Updated
# May 18, 2025
# hub-docs
# Public
# Docs of the Hugging Face Hub
# huggingface/hub-docs’s past year of commit activity
# Handlebars
# 388
# Apache-2.0
# 305
# 103
# 25
# Updated
# May 18, 2025
# nanotron
# Public
# Minimalistic large language model 3D-parallelism training
# huggingface/nanotron’s past year of commit activity
# Python
# 1,871
# Apache-2.0
# 190
# 62
# (20 issues need help)
# 53
# Updated
# May 17, 2025
# xet-core
# Public
# xet client tech, used in huggingface_hub
# huggingface/xet-core’s past year of commit activity
# Rust
# 97
# Apache-2.0
# 12
# 1
# 15
# Updated
# May 17, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 539 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Joseph Spisak
# Product Director, Generative AI @Meta | Ex: Google, Amazon
# 1w
# Edited
# Report this post
# The Open Language of AI..
#
# My journey in AI started over 10 years ago when I met
# Soumith
# ,
# Yangqing
# ,
# Dmytro
# ,
# Andrew
# and
# Pieter
# - folks that I am proud to this day to call friends and colleagues. It’s hard to believe it’s been that long and honestly hard to believe I’ve spent 7 of those years helping to build PyTorch what it is today - an amazing and inspirational project that is foundational to ChatGPT, Llama, DeepSeek, Stable Diffusion and so many other breakthroughs.
#
# In this next phase we have a much bigger and broader vision and as part of that we are bringing in vLLM and DeepSpeed under our umbrella foundation laying the groundwork for PyTorch to continue its growth trajectory with additional high caliber projects on the way.
#
# For more on how we see the future check out the vision blog that
# Luca
# and coauthored.
# https://lnkd.in/gZRmv2e9
# I’m excited to work with this community to realize our expanded vision of being the open language of AI.
#
# Thank you to everyone who made this next step possible including a few key folks -
# Ion Stoica
# ,
# Aparna Ramani
# ,
# Soumith Chintala
# ,
# Matt W.
# ,
# Simon Mo
# and
# Woosuk Kwon
# and many others..
#
# And thank you to all of the members:
# AMD
# ,
# Arm
# ,
# Amazon Web Services (AWS)
# ,
# Google
# ,
# Huawei
# ,
# Hugging Face
# ,
# IBM
# ,
# Intel Corporation
# ,
# Lightning AI
# ,
# NVIDIA
# , and
# Snowflake
# .
#
# Cheers to what's next!
#
#
#
# Details:
#
# Vision post:
# https://lnkd.in/gZRmv2e9
# Press Release -
# https://lnkd.in/gBzYkyaJ
# vLLM Announcement -
# https://lnkd.in/gCEwbq3p
# DeepSpeed Announcement -
# https://lnkd.in/gXAWTNnt
# 488
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Clem Delangue 🤗
# Clem Delangue 🤗 is an Influencer
# Co-founder & CEO at Hugging Face
# 1d
# Report this post
# 3,000+ students for the
# Hugging Face
# MCP class already!
# 298
# 20 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 2d
# Report this post
# New sota open-source depth estimation: Marigold IID 🌼
#
# > normal maps, depth maps of scenes & faces
# > get albedo (true color) and BRDF (texture) maps of scenes, they even release a depth-to-3D printer format demo 😮
# links to all models and demos in comments 🤗
# …more
# 274
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 2d
# Edited
# Report this post
# The MCP course is free, open source, and with Apache 2 license.
#
# ⭐️
# https://lnkd.in/eTuSr-Uh
# So if you’re working on MCP you can do any of this:
#
# - take the course and reuse it for your own educational/ dev advocacy projects
# - collaborate with us on new units about your projects or interests
# - star the repo on github so more devs hear about it and join in
#
# Note, some of these options are cooler than others.
# 1,117
# 17 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# GPU poor @ Hugging Face
# 3d
# Report this post
# LETS GOO: Hugging Face just dropped the MCP Course everything you need to know about Model Context Protocol AND how to use it!! 💥
#
# Sign up today - totally free and open source course!
#
# From understanding what MCP is to connecting LLMs, to deploying your own MCP servers - we've got you covered! 🤗
#
# Link to the course in comments!
# 853
# 27 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 63,637 followers
# 3d
# Report this post
# Learn about the trio powering Model Context Protocol (MCP)👇
#
# 🧠 Host = the LLM app (Claude Desktop, IDEs, even your Gradio Chatbots)
# 🧰 Server = the tool with specific capability (APIs or Gradio apps)
# 🔗 Client = maintains 1:1 connection with the Server from inside the Host
#
# Guides for further reading and building MCP-powered apps 👇
# 🚀 Create end-to-end applications with Gradio chat interface as the Host and Gradio apps as Servers:
# https://lnkd.in/gTpTJMCy
# 🔥 Create MCP Servers with Gradio for your IDEs, Claude Desktop, or custom Hosts:
# https://lnkd.in/g2yg-NGX
# 51
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 3d
# Report this post
# The Transformers library is undergoing it's largest pivot to date 🙌
#
# It now cements its role as the central model definition, irrespective of the backend and runner. One ground truth to bring more reliability across the ecosystem.
#
# This comes into play as Transformers becomes a backend of:
#
# - most popular inference engines like vLLM, SGLang, TGI, TensorRT, ...
# - training frameworks like Axolotl, Unsloth, DeepSpeed, FSDP, PyTorch-Lightning, ...
# - and adjacent modeling libraries like
# llama.cpp
# , MLX, ONNX, ...
#
# Transformers is the pivot across frameworks: if a model is integrated, then you're certain it is handled by the rest of the ecosystem.
#
# In a field where ML releases are more and more frequent, keeping track of integrations in all downstream libraries can become a headache.
#
# By having Transformers as a backend, you get immediate access to all 300+ supported architectures, and you're ensured immediate access to upcoming model releases.
#
# This often means day-0 access, but also community-fixes, and a shared baseline for evaluation.
#
# This means that we'll strive to continuously improve Transformers so that:
#
# -  Integrations are simpler & faster
# - Models continue being adaptable, customizable
# - Model definitions remain simple, easily augmented by downstream libraries.
#
# Read more about it in the following blog post:
# https://lnkd.in/eQjmcWxF
# 1,195
# 17 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 3d
# Report this post
# We're thrilled to announce the launch of our comprehensive Model Context Protocol (MCP) Course! This free program is designed to take learners from foundational understanding to practical application of MCP in AI.
#
# Join the course on the hub:
# https://lnkd.in/eTuSr-Uh
# In this course, you will:
# 📖 Study Model Context Protocol in theory, design, and practice.
# 🧑💻 Learn to use established MCP SDKs and frameworks.
# 💾 Share your projects and explore applications created by the community.
# 🏆 Participate in challenges and evaluate your MCP implementations.
# 🎓 Earn a certificate of completion.
#
# At the end, you'll understand how MCP works and how to build your own AI applications that leverage external data and tools using the latest MCP standards.
# 2,444
# 62 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Marc Sun
# ML Engineer @HuggingFace 🤗 | CentraleSupélec | Columbia
# 3d
# Report this post
# 🚀 Accelerate v1.7.0 is here!
#
# Highlights of this release:
# - 🧩 Regional compilation by
# Ilyas Moutawwakil
# - 🧠 Layerwise casting hook by
# Sayak Paul
# , a widely used feature in diffusers repository
# - ⚡QLoRA support for FSDPv2 by
# Wing Lian
# Release notes:
# https://lnkd.in/eTxrarYa
# 97
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Pollen Robotics
# 10,548 followers
# 3d
# Report this post
# 3 robots heading to
# Humanoids Summit
# London 2025!
#
# If you're around, come say hi. We'll be showing:
#  🤖 Reachy 2, now able to react emotionally and understand multiple languages. We'll also show you what Reachy is able to do through teleoperation.
#  🦆 Mini Duck,
# Antoine Pirrone
# 's project, doing what it does best: wandering freely and charming everyone.
#  🦾 And for the first time ever in public: David A6DoF, a joint project by Antoine and
# Augustin CRAMPETTE
# We’re also proud to see
# Santiago Ismael Pavon
# and
# Remi Cadene
# from
# Hugging Face
# speaking on stage, diving into some of the key topics around Embodied AI.
#
#  📍See you there?
# 65
# 4 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nnvidia/parakeet-tdt-0.6b-v2\nUpdated\n3 days ago\n•\n243k\n•\n933\nnari-labs/Dia-1.6B\nUpdated\n5 days ago\n•\n181k\n•\n2.22k\nlodestones/Chroma\nUpdated\nabout 8 hours ago\n•\n576\nPrimeIntellect/INTELLECT-2\nUpdated\n6 days ago\n•\n632\n•\n162\nWan-AI/Wan2.1-VACE-14B\nUpdated\n4 days ago\n•\n8.8k\n•\n154\nBrowse 1M+ models\nSpaces\nRunning\n6.7k\n6.7k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nCPU Upgrade\n673\n673\nComputer Agent\n🖥\nInteract with an AI agent to perform web tasks\nRunning\non\nZero\n392\n392\nDreamO\n🐨\nA Unified Framework for Image Customization\nRunning\non\nZero\n219\n219\nNSFW Uncensored image to video\n🎬\nMAX ~60sec Video - AI Limits\nRunning\n426\n426\nFLUX Pro Unlimited\n🔥\nUse the FLUX-Pro model as much as you want.\nBrowse 400k+ applications\nDatasets\nopenbmb/Ultra-FineWeb\nUpdated\n10 days ago\n•\n6.63k\n•\n67\nPrimeIntellect/INTELLECT-2-RL-Dataset\nUpdated\n6 days ago\n•\n517\n•\n44\nnvidia/OpenCodeReasoning\nUpdated\n14 days ago\n•\n12.7k\n•\n415\nnvidia/OpenMathReasoning\nUpdated\n9 days ago\n•\n38.4k\n•\n236\nDMindAI/DMind_Benchmark\nUpdated\n1 day ago\n•\n2.27k\n•\n75\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n757 models\n•\n3.28k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.12k models\n•\n5.99k followers\nAmazon\ncompany\n•\n20 models\n•\n3.17k followers\nGoogle\ncompany\n•\n991 models\n•\n13.3k followers\nIntel\ncompany\n•\n221 models\n•\n2.54k followers\nMicrosoft\ncompany\n•\n374 models\n•\n12.4k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n160 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n267 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n144,477\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n29,022\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,269\nSafe way to store/distribute neural network weights\nHub Python Library\n2,601\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,685\nFast tokenizers optimized for research & production\nTRL\n13,792\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,610\nState-of-the-art ML running directly in your browser\nsmolagents\n18,787\nSmol library to build great agents in Python\nPEFT\n18,437\nParameter-efficient finetuning for large language models\nDatasets\n20,128\nAccess & share datasets for any ML tasks\nText Generation  ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))
    return result

# %%
result = create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'discussion forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ---
#
# ### **Welcome to Hugging Face!**
# *The AI community building the future.*
#
# Hugging Face is a leading platform dedicated to the machine learning (ML) community, fostering collaboration on models, datasets, and applications.
#
# ---
#
# ### **What We Do**
#
# - **Models:** Explore over **1 million** models and **400k+ applications**.
# - **Datasets:** Access and share **250k+ datasets** tailored for any ML tasks.
# - **Spaces:** Run and collaborate on various applications and AI projects seamlessly.
#
# We provide essential tools and a collaborative environment to accelerate your ML journey, whether you are an individual researcher or part of an enterprise team.
#
# ---
#
# ### **Our Community of Customers**
#
# Join over **50,000 organizations** that trust Hugging Face, including:
#
# - **AI2**
# - **Meta**
# - **Amazon**
# - **Google**
# - **Intel**
# - **Microsoft**
#
# Our clients range from startups to major corporations looking to harness state-of-the-art AI capabilities for their projects and products.
#
# ---
#
# ### **Why Choose Us?**
#
# - **Open Source Foundation:** We are committed to building robust ML tooling with community contributions, including popular libraries such as Transformers and Diffusers.
# - **Enterprise Solutions:** We offer tailored enterprise-grade security features, access controls, and dedicated support, starting at **$20/user/month**.
# - **Infrastructure:** Deploy your models on optimized inference endpoints for efficient model serving at competitive pricing starting from **$0.60/hour for GPU**.
#
# ---
#
# ### **Company Culture**
#
# At Hugging Face, we embrace a culture of innovation, collaboration, and accessibility. We believe in the power of the community and aim to empower individuals and organizations alike. Our team is driven, passionate about AI, and dedicated to building the future of machine learning.
#
# ---
#
# ### **Careers at Hugging Face**
#
# We are constantly on the lookout for talented individuals who share our vision and commitment to advancing AI. Join us and help shape the future! Check our [Jobs page](https://huggingface.co/jobs) to explore open positions.
#
# ---
#
# ### **Get Involved!**
#
# - **Explore our Models and Datasets:** Sign up to browse and contribute today!
# - **Join our Community:** Follow us on [GitHub](https://github.com/huggingface), [Twitter](https://twitter.com/huggingface), or connect with us on [Discord](https://discord.gg/huggingface).
#
# ### **Contact Us**
#
# For more information, visit our [website](https://huggingface.co) or reach out through our community forum.
#
# ---
#
# *Together, let's build the future of AI at Hugging Face!*

# %%
result
# Out:
# "# Hugging Face Company Brochure\n\n---\n\n### **Welcome to Hugging Face!**\n*The AI community building the future.*\n\nHugging Face is a leading platform dedicated to the machine learning (ML) community, fostering collaboration on models, datasets, and applications.\n\n---\n\n### **What We Do**\n\n- **Models:** Explore over **1 million** models and **400k+ applications**.\n- **Datasets:** Access and share **250k+ datasets** tailored for any ML tasks.\n- **Spaces:** Run and collaborate on various applications and AI projects seamlessly.\n\nWe provide essential tools and a collaborative environment to accelerate your ML journey, whether you are an individual researcher or part of an enterprise team.\n\n---\n\n### **Our Community of Customers**\n\nJoin over **50,000 organizations** that trust Hugging Face, including:\n\n- **AI2**\n- **Meta**\n- **Amazon**\n- **Google**\n- **Intel**\n- **Microsoft**\n\nOur clients range from startups to major corporations looking to harness state-of-the-art AI capabilities for their projects and products.\n\n---\n\n### **Why Choose Us?**\n\n- **Open Source Foundation:** We are committed to building robust ML tooling with community contributions, including popular libraries such as Transformers and Diffusers.\n- **Enterprise Solutions:** We offer tailored enterprise-grade security features, access controls, and dedicated support, starting at **$20/user/month**.\n- **Infrastructure:** Deploy your models on optimized inference endpoints for efficient model serving at competitive pricing starting from **$0.60/hour for GPU**.\n\n---\n\n### **Company Culture**\n\nAt Hugging Face, we embrace a culture of innovation, collaboration, and accessibility. We believe in the power of the community and aim to empower individuals and organizations alike. Our team is driven, passionate about AI, and dedicated to building the future of machine learning.\n\n---\n\n### **Careers at Hugging Face**\n\nWe are constantly on the lookout for talented individuals who share our vision and commitment to advancing AI. Join us and help shape the future! Check our [Jobs page](https://huggingface.co/jobs) to explore open positions.\n\n---\n\n### **Get Involved!**\n\n- **Explore our Models and Datasets:** Sign up to browse and contribute today!\n- **Join our Community:** Follow us on [GitHub](https://github.com/huggingface), [Twitter](https://twitter.com/huggingface), or connect with us on [Discord](https://discord.gg/huggingface).\n\n### **Contact Us**\n\nFor more information, visit our [website](https://huggingface.co) or reach out through our community forum.\n\n---\n\n*Together, let's build the future of AI at Hugging Face!*"

# %%
from ollama import chat
from ollama import ChatResponse

def brochure_to_hebrew(brochure_txt):
    response: ChatResponse = chat(model='mistral-nemo', messages=[
      {
        'role': 'user',
        'content': 'Please translate the following to Hebrew: ' + brochure_txt,
      },
    ])
    print(response['message']['content'])
    # or access fields directly from the response object
    print(response.message.content)

# %%
display(Markdown(brochure_to_hebrew(result)))
# Out:
# Here is the translation to Hebrew:
#
# ---
#
# ### **ברוך הבא ל-Hugging Face!**
# *קהילת ה-AI בנות את העתיד.*
#
# Hugging Face היא פלטפורמה המובילה המוקדשת לקהילת המכשיר הלמידה (ML), תוך עידוד שיתוף פעולה על מודלים, קובצי נתונים ואפליקציות.
#
# ---
#
# ### **מה אנחנו עושים?**
#
# - **מודלים:** הגלייה בתוך יותר מ**1 מיליון** מודלים ומקלדות של **400,000+** אפליקציות.
# - **קובצי נתונים:** גישה ושתף כ**250,000+** קובצי נתונים המותאמים לכל משימות ML.
# - **חזותים:** הרן ותשתף על אפליקציות שונות ומפגשים AI בצורה חלקה.
#
# אנחנו מספקים כלים בסיסיים וסביבת שיתוף פעולה כדי להזריז את לימודך המכשיר, בין אם אתה חוקר יחיד או部分 צוות חיל של חברת גדולה.
#
# ---
#
# ### **קהילת הלקוחות שלנו**
#
# הצטרף אל יותר מ**50,000 ארגונים** שמתיקים ב-Hugging Face, כולל:
#
# - **AI2**
# - **מטה**
# - **אמזון**
# - **גרוג'לה**
# - **אינטל**
# - **מיקרוסופט**
#
# לקוחותינו טווחים מאנשי העסקים ליצירות גדולות שזקוקות לקבל הובלה של AI מעודפת לפרויקטים ולמוצרים שלהם.
#
# ---
#
# ### **למה להבחר בנו?**
#
# - **גראונד אפן סורסאיב:** אנחנו קבועים לבנות כלים איכותיים ומפותחים ביחד עם הקהילה, כולל ספריות פופולריות כגון Transformers ו-Diffusers.
# - **פתרונות חוזרת עסקי:** אנחנו מציעים סגירה מותאמת ואמצעי יישום עבור עסקאות גדולות ושירות נדחה מתחיל ב**$20/משתמש/חודש**.
# - **מבנה:** הרן את מודלך על נקודות שרת אופטימיות לקבל יעילות של כזב סרבר עבור מחיר תחרותי מתחיל ב**$0.60/שעה ל-GPU**.
#
# ---
#
# ### **תרבות החברה**
#
# בה-Hugging Face, אנו משעטים תרבות של עוררות, שיתוף פעולה ואCCESSIBILITY. אנו מאמינים בשאיפה הקהילה ומנסים להעניק כוחות לבני אדם ולארגונים כאחד. צוואריינו מוטרדים, חושבים על AI והשתתפים בבניית העתיד של לימוד מכשיר.
#
# ---
#
# ### **פעילות אצל Hugging Face**
#
# אנחנו תמיד בורחים אחר אישיות מצטיינות שמשעטים את חזוננו ואת מחויבותה שלנו להעלות את ה-AI. בא אלינו ושב בעזרתך לעצבץ את העתיד! ראה את עמוד [הפעילות](https://huggingface.co/jobs) כדי לגלות את הקורסים הפתוחים.
#
# ---
#
# ### **היכנס לפעולה!**
#
# - **הגלייה במודלים ובקובצי נתונים:** הגש אצבע כדי לבקר ולשאת מיד!
# - **הצטרף לקהילתנו:** עקוב אחרינו ב-[GitHub](https://github.com/huggingface), [טוויטר](https://twitter.com/huggingface) או קשר עםינו בעזרתנו בדיסקורד.
#
# ### **יצירת קשר**
#
# voor meer informatie, bezoek onze [website](https://huggingface.co) of neem contact met ons door middel van forum in de gemeenschap.
#
# ---
#
# *יחד, ניצח את הבניית העתיד של AI ב-Hugging Face!*
# Here is the translation to Hebrew:
#
# ---
#
# ### **ברוך הבא ל-Hugging Face!**
# *קהילת ה-AI בנות את העתיד.*
#
# Hugging Face היא פלטפורמה המובילה המוקדשת לקהילת המכשיר הלמידה (ML), תוך עידוד שיתוף פעולה על מודלים, קובצי נתונים ואפליקציות.
#
# ---
#
# ### **מה אנחנו עושים?**
#
# - **מודלים:** הגלייה בתוך יותר מ**1 מיליון** מודלים ומקלדות של **400,000+** אפליקציות.
# - **קובצי נתונים:** גישה ושתף כ**250,000+** קובצי נתונים המותאמים לכל משימות ML.
# - **חזותים:** הרן ותשתף על אפליקציות שונות ומפגשים AI בצורה חלקה.
#
# אנחנו מספקים כלים בסיסיים וסביבת שיתוף פעולה כדי להזריז את לימודך המכשיר, בין אם אתה חוקר יחיד או部分 צוות חיל של חברת גדולה.
#
# ---
#
# ### **קהילת הלקוחות שלנו**
#
# הצטרף אל יותר מ**50,000 ארגונים** שמתיקים ב-Hugging Face, כולל:
#
# - **AI2**
# - **מטה**
# - **אמזון**
# - **גרוג'לה**
# - **אינטל**
# - **מיקרוסופט**
#
# לקוחותינו טווחים מאנשי העסקים ליצירות גדולות שזקוקות לקבל הובלה של AI מעודפת לפרויקטים ולמוצרים שלהם.
#
# ---
#
# ### **למה להבחר בנו?**
#
# - **גראונד אפן סורסאיב:** אנחנו קבועים לבנות כלים איכותיים ומפותחים ביחד עם הקהילה, כולל ספריות פופולריות כגון Transformers ו-Diffusers.
# - **פתרונות חוזרת עסקי:** אנחנו מציעים סגירה מותאמת ואמצעי יישום עבור עסקאות גדולות ושירות נדחה מתחיל ב**$20/משתמש/חודש**.
# - **מבנה:** הרן את מודלך על נקודות שרת אופטימיות לקבל יעילות של כזב סרבר עבור מחיר תחרותי מתחיל ב**$0.60/שעה ל-GPU**.
#
# ---
#
# ### **תרבות החברה**
#
# בה-Hugging Face, אנו משעטים תרבות של עוררות, שיתוף פעולה ואCCESSIBILITY. אנו מאמינים בשאיפה הקהילה ומנסים להעניק כוחות לבני אדם ולארגונים כאחד. צוואריינו מוטרדים, חושבים על AI והשתתפים בבניית העתיד של לימוד מכשיר.
#
# ---
#
# ### **פעילות אצל Hugging Face**
#
# אנחנו תמיד בורחים אחר אישיות מצטיינות שמשעטים את חזוננו ואת מחויבותה שלנו להעלות את ה-AI. בא אלינו ושב בעזרתך לעצבץ את העתיד! ראה את עמוד [הפעילות](https://huggingface.co/jobs) כדי לגלות את הקורסים הפתוחים.
#
# ---
#
# ### **היכנס לפעולה!**
#
# - **הגלייה במודלים ובקובצי נתונים:** הגש אצבע כדי לבקר ולשאת מיד!
# - **הצטרף לקהילתנו:** עקוב אחרינו ב-[GitHub](https://github.com/huggingface), [טוויטר](https://twitter.com/huggingface) או קשר עםינו בעזרתנו בדיסקורד.
#
# ### **יצירת קשר**
#
# voor meer informatie, bezoek onze [website](https://huggingface.co) of neem contact met ons door middel van forum in de gemeenschap.
#
# ---
#
# *יחד, ניצח את הבניית העתיד של AI ב-Hugging Face!*

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
